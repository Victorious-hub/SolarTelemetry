# %%
# %run solarnn_train.py
# Out:
# August_2019 1 / 1
# (364, 200, 5)
# 364 test records found
# (9, 200, 5)
# 9 test records found
# [[[[1.6700e+02]
#    [4.1100e+01]
#    [3.2700e+01]
#    [3.0500e+00]
#    [6.3743e+02]]
#
#   [[1.7100e+02]
#    [4.1600e+01]
#    [3.2600e+01]
#    [3.1300e+00]
#    [6.5023e+02]]
#
#   [[1.7300e+02]
#    [4.1600e+01]
#    [3.2700e+01]
#    [3.1700e+00]
#    [6.5661e+02]]
#
#   ...
#
#   [[6.4900e+02]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]]
#
#   [[6.5000e+02]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]]
#
#   [[6.5100e+02]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]]]
#
#
#  [[[9.5000e+01]
#    [2.5500e+01]
#    [4.0300e+01]
#    [4.2000e-01]
#    [3.6351e+02]]
#
#   [[1.1300e+02]
#    [2.7000e+01]
#    [3.5200e+01]
#    [1.9700e+00]
#    [4.3007e+02]]
#
#   [[1.3400e+02]
#    [2.9500e+01]
#    [3.4700e+01]
#    [2.3600e+00]
#    [5.0943e+02]]
#
#   ...
#
#   [[6.5600e+02]
#    [0.0000e+00]
# ...

# %%
# %run solarnn_decode.py
# Out:
# August_2019 1 / 1
# (364, 200, 5)
# 364 test records found
# (9, 200, 5)
# 9 test records found
# [[[[1.6700e+02]
#    [4.1100e+01]
#    [3.2700e+01]
#    [3.0500e+00]
#    [6.3743e+02]]
#
#   [[1.7100e+02]
#    [4.1600e+01]
#    [3.2600e+01]
#    [3.1300e+00]
#    [6.5023e+02]]
#
#   [[1.7300e+02]
#    [4.1600e+01]
#    [3.2700e+01]
#    [3.1700e+00]
#    [6.5661e+02]]
#
#   ...
#
#   [[6.4900e+02]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]]
#
#   [[6.5000e+02]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]]
#
#   [[6.5100e+02]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]
#    [0.0000e+00]]]
#
#
#  [[[9.5000e+01]
#    [2.5500e+01]
#    [4.0300e+01]
#    [4.2000e-01]
#    [3.6351e+02]]
#
#   [[1.1300e+02]
#    [2.7000e+01]
#    [3.5200e+01]
#    [1.9700e+00]
#    [4.3007e+02]]
#
#   [[1.3400e+02]
#    [2.9500e+01]
#    [3.4700e+01]
#    [2.3600e+00]
#    [5.0943e+02]]
#
#   ...
#
#   [[6.5600e+02]
#    [0.0000e+00]
# ...
