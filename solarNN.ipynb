# %%
# %run solarnn_train.py
# Out:
# August_2019 1 / 6
# 364 test records found
# 9 test records found
# July_2019 2 / 6
# 435 test records found
# 9 test records found
# June_2019 3 / 6
# 3 test records found
# 0 test records found
# November_2019 4 / 6
# 0 test records found
# 0 test records found
# October_2019 5 / 6
# 455 test records found
# 10 test records found
# September_2019 6 / 6
# 369 test records found
# 9 test records found
# 51/51 [==============================] - ETA: 0s - loss: 15016.3896
# Epoch 1: loss improved from inf to 15016.38965, saving model to ./weights\weights_solar.h5
# 51/51 [==============================] - 1s 13ms/step - loss: 15016.3896 - val_loss: 1586.6888

# %%
# %run solarnn_decode.py
# Out:
# August_2019 1 / 6
# 364 test records found
# 9 test records found
# July_2019 2 / 6
# 435 test records found
# 9 test records found
# June_2019 3 / 6
# 3 test records found
# 0 test records found
# November_2019 4 / 6
# 0 test records found
# 0 test records found
# October_2019 5 / 6
# 455 test records found
# 10 test records found
# September_2019 6 / 6
# 369 test records found
# 9 test records found
# 51/51 [==============================] - 1s 7ms/step - loss: 14844.4961 - val_loss: 1565.2299
# Directory 'test' for results created...
# Initial data saved to: test.csv
# Decoded data saved to: test_decoded.csv
# C:\Users\Asus\PycharmProjects\SolarTelemetry\solarnn_decode.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   index.append(float(r[0]))
# ...
